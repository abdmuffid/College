# %% [markdown]
# ### Libraries

# %%
import numpy as np
import os
import cv2
import random
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from sklearn.preprocessing import LabelEncoder
from keras.layers import Dense, Flatten, Dense, AveragePooling2D
from keras.layers import Conv2D

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset

# %%
img_size = 124
train_data = []
val_data = []
test_data = []
directory = "../Dataset/flowers"
for sub_directory in os.listdir(directory):
    count = 0
    inner_directory = os.path.join(directory,sub_directory)
    test_limit = int(0.85*(len(os.listdir(inner_directory))))
    val_limit = int(0.8*test_limit)
    for i in os.listdir(inner_directory):
        try:
            count += 1
            img = cv2.imread(os.path.join(inner_directory,i),1)
            img = cv2.resize(img,(img_size,img_size))
            if count < val_limit:
                train_data.append([img,sub_directory])
            elif val_limit <= count < test_limit:
                val_data.append([img,sub_directory])
            else:
                test_data.append([img,sub_directory])
        except:
            pass

# %% [markdown]
# ### Shuffle Data

# %%
random.shuffle(train_data)
random.shuffle(val_data)
random.shuffle(test_data)

# %% [markdown]
# ### Split Train, Val, and Test

# %%
train_X = []
train_Y = []
for features,label in train_data:
    train_X.append(features)
    train_Y.append(label)

val_X = []
val_Y = []
for features,label in val_data:
    val_X.append(features)
    val_Y.append(label)

test_X = []
test_Y = []
for features,label in test_data:
    test_X.append(features)
    test_Y.append(label)

# %% [markdown]
# ### Reshape

# %%
train_X = np.array(train_X)/255.0
train_X = train_X.reshape(-1,124,124,3)
train_Y = np.array(train_Y)

val_X = np.array(val_X)/255.0
val_X = val_X.reshape(-1,124,124,3)
val_Y = np.array(val_Y)

test_X = np.array(test_X)/255.0
test_X = test_X.reshape(-1,124,124,3)
test_Y = np.array(test_Y)

# %% [markdown]
# ### Check Shape

# %%
train_X.shape
# Out:
# (2927, 124, 124, 3)

# %% [markdown]
# ### Check Image

# %%
w=10
h=10
fig=plt.figure(figsize=(12,12))
columns = 5
rows = 5

for i in range(1, columns*rows +1):
    img = train_X[i]
    fig.add_subplot(rows, columns, i)
    plt.imshow(np.squeeze(img))
    
plt.show()

# %% [markdown]
# ### Label Encoder

# %%
LE = LabelEncoder()
train_Y = LE.fit_transform(train_Y)
test_Y = LE.fit_transform(test_Y)
val_Y = LE.fit_transform(val_Y)
train_Y = to_categorical(train_Y)
test_Y = to_categorical(test_Y)
val_Y = to_categorical(val_Y)

# %% [markdown]
# ### Model - LeNet-5

# %%
model_LeNet = Sequential()
model_LeNet.add(Conv2D(6, kernel_size = (5, 5), strides = 1, activation ='tanh',
                    input_shape = (124, 124, 3), padding = 'same'))
model_LeNet.add(AveragePooling2D(pool_size = (2, 2)))
model_LeNet.add(Conv2D(16, kernel_size = (5, 5), strides = 1,
                    activation = 'tanh', padding = 'valid'))
model_LeNet.add(AveragePooling2D(pool_size = (2, 2)))
model_LeNet.add(Conv2D(120, kernel_size = (5, 5), activation = 'tanh'))
model_LeNet.add(Flatten())
model_LeNet.add(Dense(84, activation = 'tanh'))
model_LeNet.add(Dense(5, activation = 'softmax')) #change to class

# %% [markdown]
# ### Check Model

# %%
model_LeNet.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 124, 124, 6)    │           456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d               │ (None, 62, 62, 6)      │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 58, 58, 16)     │         2,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_1             │ (None, 29, 29, 16)     │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 25, 25, 120)    │        48,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 75000)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 84)             │     6,300,084 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           425 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,351,501 (24.23 MB)
#  Trainable params: 6,351,501 (24.23 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Model Compile

# %%
model_LeNet.compile(loss='categorical_crossentropy',
                    optimizer="adam",metrics=['accuracy'])

# %% [markdown]
# ### Model Datagen

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=False,
    vertical_flip=False)

datagen.fit(train_X)

# %% [markdown]
# ### History Model

# %%
history_model_LeNet = model_LeNet.fit(
    datagen.flow(train_X,train_Y, batch_size = 64) ,
    epochs = 30 , validation_data = datagen.flow(val_X, val_Y))
# Out:
# Epoch 1/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 12s 219ms/step - accuracy: 0.2614 - loss: 3.3294 - val_accuracy: 0.3152 - val_loss: 1.5636
# Epoch 2/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 10s 215ms/step - accuracy: 0.3414 - loss: 1.4782 - val_accuracy: 0.3166 - val_loss: 1.4810
# Epoch 3/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 10s 214ms/step - accuracy: 0.3289 - loss: 1.4537 - val_accuracy: 0.3166 - val_loss: 1.4761
# Epoch 4/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - accuracy: 0.3683 - loss: 1.4298 - val_accuracy: 0.3139 - val_loss: 1.4819
# Epoch 5/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 214ms/step - accuracy: 0.3539 - loss: 1.4453 - val_accuracy: 0.3845 - val_loss: 1.4171
# Epoch 6/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 32s 698ms/step - accuracy: 0.3608 - loss: 1.4307 - val_accuracy: 0.3370 - val_loss: 1.4393
# Epoch 7/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 26s 555ms/step - accuracy: 0.3493 - loss: 1.4476 - val_accuracy: 0.2948 - val_loss: 1.5020
# Epoch 8/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 26s 568ms/step - accuracy: 0.3038 - loss: 1.4803 - val_accuracy: 0.2812 - val_loss: 1.5350
# Epoch 9/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.3033 - loss: 1.4642 - val_accuracy: 0.3424 - val_loss: 1.4227
# Epoch 10/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.3451 - loss: 1.4153 - val_accuracy: 0.2880 - val_loss: 1.5082
# Epoch 11/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 34s 752ms/step - accuracy: 0.3108 - loss: 1.5089 - val_accuracy: 0.2255 - val_loss: 1.7994
# Epoch 12/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 275ms/step - accuracy: 0.3043 - loss: 1.6610 - val_accuracy: 0.1821 - val_loss: 1.6259
# Epoch 13/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 30s 659ms/step - accuracy: 0.2392 - loss: 1.6124 - val_accuracy: 0.2296 - val_loss: 1.6029
# Epoch 14/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 10s 226ms/step - accuracy: 0.2212 - loss: 1.6053 - val_accuracy: 0.2418 - val_loss: 1.6035
# Epoch 15/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 247ms/step - accuracy: 0.2522 - loss: 1.6046 - val_accuracy: 0.2418 - val_loss: 1.6034
# Epoch 16/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 39s 864ms/step - accuracy: 0.2406 - loss: 1.6062 - val_accuracy: 0.2405 - val_loss: 1.6037
# Epoch 17/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 10s 222ms/step - accuracy: 0.2397 - loss: 1.6051 - val_accuracy: 0.2418 - val_loss: 1.6040
# Epoch 18/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 325ms/step - accuracy: 0.2462 - loss: 1.6028 - val_accuracy: 0.2405 - val_loss: 1.6010
# Epoch 19/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 12s 271ms/step - accuracy: 0.2369 - loss: 1.6037 - val_accuracy: 0.2405 - val_loss: 1.6035
# Epoch 20/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 281ms/step - accuracy: 0.2339 - loss: 1.6031 - val_accuracy: 0.2405 - val_loss: 1.6065
# Epoch 21/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 32s 713ms/step - accuracy: 0.2399 - loss: 1.6019 - val_accuracy: 0.2418 - val_loss: 1.5997
# Epoch 22/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.2412 - loss: 1.6024 - val_accuracy: 0.2269 - val_loss: 1.6128
# Epoch 23/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 53s 401ms/step - accuracy: 0.2389 - loss: 1.6007 - val_accuracy: 0.2405 - val_loss: 1.6104
# Epoch 24/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 309ms/step - accuracy: 0.2369 - loss: 1.6062 - val_accuracy: 0.2283 - val_loss: 1.6130
# Epoch 25/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 305ms/step - accuracy: 0.2401 - loss: 1.6010 - val_accuracy: 0.2269 - val_loss: 1.6037
# Epoch 26/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 304ms/step - accuracy: 0.2315 - loss: 1.6019 - val_accuracy: 0.2405 - val_loss: 1.6077
# Epoch 27/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 17s 376ms/step - accuracy: 0.2339 - loss: 1.6009 - val_accuracy: 0.2405 - val_loss: 1.6163
# Epoch 28/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 27s 588ms/step - accuracy: 0.2466 - loss: 1.6037 - val_accuracy: 0.2405 - val_loss: 1.6152
# Epoch 29/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 17s 363ms/step - accuracy: 0.2301 - loss: 1.6100 - val_accuracy: 0.2405 - val_loss: 1.6051
# Epoch 30/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 32s 703ms/step - accuracy: 0.2392 - loss: 1.6018 - val_accuracy: 0.2405 - val_loss: 1.6080

# %% [markdown]
# ### Plot Accuracy

# %%
plt.plot(history_model_LeNet.history['accuracy'])
plt.plot(history_model_LeNet.history['val_accuracy'])
plt.title('Training Accuracy vs Validation Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Plot Loss

# %%
plt.plot(history_model_LeNet.history['loss'])
plt.plot(history_model_LeNet.history['val_loss'])
plt.title('Training Loss vs Validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Accuracy and Loss

# %%
score = model_LeNet.evaluate(test_X, test_Y, verbose=0)
print("Loss: " + str(score[0]))
print("Accuracy: " + str(score[1]*100) + "%")
# Out:
# Loss: 1.602734088897705
# Accuracy: 24.46483224630356%

# %% [markdown]
# ### Model ResNet

# %%
from tensorflow.keras import layers, models
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, ReLU, Add, Flatten, Dense
from tensorflow.keras.models import Model

# Fungsi untuk residual block
def residual_block(x, filters, kernel_size=3, stride=1):
    shortcut = x  # Shortcut connection

    # Lapisan pertama
    x = Conv2D(filters, kernel_size=kernel_size, strides=stride, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    # Lapisan kedua
    x = Conv2D(filters, kernel_size=kernel_size, strides=1, padding='same')(x)
    x = BatchNormalization()(x)

    # Shortcut connection jika dimensi input berbeda
    if stride != 1 or x.shape[-1] != shortcut.shape[-1]:
        shortcut = Conv2D(filters, kernel_size=1, strides=stride, padding='same')(shortcut)
        shortcut = BatchNormalization()(shortcut)

    # Tambahkan shortcut
    x = Add()([x, shortcut])
    x = ReLU()(x)
    return x

# Arsitektur ResNet
input_shape = (124, 124, 3)
num_classes = 5

inputs = Input(shape=input_shape)

# Layer awal
x = Conv2D(64, kernel_size=7, strides=2, padding='same')(inputs)
x = BatchNormalization()(x)
x = ReLU()(x)
x = layers.MaxPooling2D(pool_size=(3, 3), strides=2, padding='same')(x)

# Tambahkan beberapa residual blocks
x = residual_block(x, filters=64)
x = residual_block(x, filters=128, stride=2)
x = residual_block(x, filters=256, stride=2)
x = residual_block(x, filters=512, stride=2)

# Layer fully connected untuk klasifikasi
x = layers.GlobalAveragePooling2D()(x)
x = Dense(84, activation='relu')(x)  # Lapisan tambahan opsional
outputs = Dense(num_classes, activation='softmax')(x)

# Buat model
model_ResNet = Model(inputs, outputs)

# Kompilasi model
model_ResNet.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Ringkasan model
model_ResNet.summary()
# Out:
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 124, 124,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 62, 62,    │      9,472 │ input_layer_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 62, 62,    │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 62, 62,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 31, 31,    │          0 │ re_lu[0][0]       │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 31, 31,    │     36,928 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 31, 31,    │        256 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 31, 31,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 31, 31,    │     36,928 │ re_lu_1[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 31, 31,    │        256 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 31, 31,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ max_pooling2d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 31, 31,    │          0 │ add[0][0]         │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 16, 16,    │     73,856 │ re_lu_2[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │    147,584 │ re_lu_3[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │      8,320 │ re_lu_2[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 16, 16,    │          0 │ add_1[0][0]       │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 8, 8, 256) │    295,168 │ re_lu_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 8, 8, 256) │    590,080 │ re_lu_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 8, 8, 256) │     33,024 │ re_lu_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 8, 8, 256) │          0 │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 4, 4, 512) │  1,180,160 │ re_lu_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 512) │      2,048 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 4, 4, 512) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 4, 4, 512) │  2,359,808 │ re_lu_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 4, 4, 512) │    131,584 │ re_lu_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 512) │      2,048 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 512) │      2,048 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 4, 4, 512) │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 4, 4, 512) │          0 │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ re_lu_8[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 84)        │     43,092 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 5)         │        425 │ dense_2[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,957,949 (18.91 MB)
#  Trainable params: 4,952,189 (18.89 MB)
#  Non-trainable params: 5,760 (22.50 KB)

# %% [markdown]
# ### History Model ResNet

# %%
history_model_ResNet = model_ResNet.fit(
    datagen.flow(train_X, train_Y, batch_size=64),
    epochs=30,
    validation_data=datagen.flow(val_X, val_Y)
)
# Out:
# Epoch 1/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 126s 3s/step - accuracy: 0.4189 - loss: 1.4776 - val_accuracy: 0.2432 - val_loss: 2.1642
# Epoch 2/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 181s 4s/step - accuracy: 0.5878 - loss: 1.0243 - val_accuracy: 0.2432 - val_loss: 2.9715
# Epoch 3/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.6408 - loss: 0.9368 - val_accuracy: 0.2432 - val_loss: 2.9112
# Epoch 4/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 39s 846ms/step - accuracy: 0.6761 - loss: 0.8708 - val_accuracy: 0.2541 - val_loss: 2.8511
# Epoch 5/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 40s 864ms/step - accuracy: 0.7074 - loss: 0.7830 - val_accuracy: 0.3220 - val_loss: 3.1131
# Epoch 6/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 39s 839ms/step - accuracy: 0.6756 - loss: 0.8319 - val_accuracy: 0.4307 - val_loss: 2.0692
# Epoch 7/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 38s 829ms/step - accuracy: 0.7404 - loss: 0.7115 - val_accuracy: 0.4810 - val_loss: 1.4966
# Epoch 8/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 39s 845ms/step - accuracy: 0.7087 - loss: 0.7282 - val_accuracy: 0.4946 - val_loss: 1.5985
# Epoch 9/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 38s 823ms/step - accuracy: 0.7297 - loss: 0.7106 - val_accuracy: 0.5761 - val_loss: 1.0552
# Epoch 10/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 38s 835ms/step - accuracy: 0.7388 - loss: 0.6792 - val_accuracy: 0.5136 - val_loss: 1.6708
# Epoch 11/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 39s 849ms/step - accuracy: 0.7482 - loss: 0.6797 - val_accuracy: 0.5448 - val_loss: 1.2728
# Epoch 12/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 41s 883ms/step - accuracy: 0.7574 - loss: 0.6294 - val_accuracy: 0.5245 - val_loss: 1.6061
# Epoch 13/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.7738 - loss: 0.6017 - val_accuracy: 0.4810 - val_loss: 1.7302
# Epoch 14/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - accuracy: 0.8034 - loss: 0.5409 - val_accuracy: 0.2840 - val_loss: 5.4397
# Epoch 15/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 40s 875ms/step - accuracy: 0.7794 - loss: 0.5569 - val_accuracy: 0.4973 - val_loss: 1.5431
# Epoch 16/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 39s 843ms/step - accuracy: 0.7860 - loss: 0.5531 - val_accuracy: 0.5272 - val_loss: 1.4323
# Epoch 17/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 39s 859ms/step - accuracy: 0.7920 - loss: 0.5199 - val_accuracy: 0.6128 - val_loss: 1.0948
# Epoch 18/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 38s 836ms/step - accuracy: 0.8135 - loss: 0.5115 - val_accuracy: 0.4022 - val_loss: 2.4120
# Epoch 19/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 38s 832ms/step - accuracy: 0.8350 - loss: 0.4501 - val_accuracy: 0.6196 - val_loss: 1.2170
# Epoch 20/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 37s 816ms/step - accuracy: 0.8273 - loss: 0.4610 - val_accuracy: 0.3845 - val_loss: 2.4020
# Epoch 21/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 39s 838ms/step - accuracy: 0.8259 - loss: 0.4829 - val_accuracy: 0.5014 - val_loss: 2.6166
# Epoch 22/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 38s 835ms/step - accuracy: 0.8452 - loss: 0.4246 - val_accuracy: 0.6209 - val_loss: 1.2132
# Epoch 23/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 38s 822ms/step - accuracy: 0.8466 - loss: 0.4098 - val_accuracy: 0.6943 - val_loss: 0.9764
# Epoch 24/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 38s 833ms/step - accuracy: 0.8592 - loss: 0.3688 - val_accuracy: 0.6970 - val_loss: 0.9017
# Epoch 25/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 39s 846ms/step - accuracy: 0.8584 - loss: 0.3766 - val_accuracy: 0.4946 - val_loss: 2.3994
# Epoch 26/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 345s 8s/step - accuracy: 0.8663 - loss: 0.3735 - val_accuracy: 0.6603 - val_loss: 1.0847
# Epoch 27/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 881s 19s/step - accuracy: 0.8755 - loss: 0.3399 - val_accuracy: 0.7201 - val_loss: 0.8948
# Epoch 28/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1000s 22s/step - accuracy: 0.8801 - loss: 0.3092 - val_accuracy: 0.5829 - val_loss: 1.4079
# Epoch 29/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 887s 18s/step - accuracy: 0.8905 - loss: 0.2926 - val_accuracy: 0.6454 - val_loss: 1.5971
# Epoch 30/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 769s 17s/step - accuracy: 0.8904 - loss: 0.2889 - val_accuracy: 0.7201 - val_loss: 0.9137

# %% [markdown]
# ### Plot Accuracy

# %%
plt.plot(history_model_ResNet.history['accuracy'])
plt.plot(history_model_ResNet.history['val_accuracy'])
plt.title('Training Accuracy vs Validation Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Plot Loss

# %%
plt.plot(history_model_ResNet.history['loss'])
plt.plot(history_model_ResNet.history['val_loss'])
plt.title('Training Loss vs Validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Accuracy and Loss

# %%
score = model_ResNet.evaluate(test_X, test_Y, verbose=0)
print("Loss: " + str(score[0]))
print("Accuracy: " + str(score[1]*100) + "%")
# Out:
# Loss: 0.7673749327659607
# Accuracy: 76.91131234169006%

# %% [markdown]
# ### Model VGG

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# VGG
model_VGG = Sequential()

# Block 1
model_VGG.add(Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=(124, 124, 3)))
model_VGG.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model_VGG.add(MaxPooling2D(pool_size=(2, 2), strides=2))

# Block 2
model_VGG.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model_VGG.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model_VGG.add(MaxPooling2D(pool_size=(2, 2), strides=2))

# Block 3
model_VGG.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model_VGG.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model_VGG.add(MaxPooling2D(pool_size=(2, 2), strides=2))

# Fully Connected Layers
model_VGG.add(Flatten())
model_VGG.add(Dense(256, activation='relu'))  # Ukuran lebih kecil dibanding VGG asli
model_VGG.add(Dropout(0.5))
model_VGG.add(Dense(5, activation='softmax'))  # Output 5 kelas

# Kompilasi model
model_VGG.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Ringkasan model
model_VGG.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_15 (Conv2D)              │ (None, 124, 124, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 124, 124, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 62, 62, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 62, 62, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_18 (Conv2D)              │ (None, 62, 62, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 31, 31, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 31, 31, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 31, 31, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 15, 15, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 57600)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │    14,745,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,892,549 (60.63 MB)
#  Trainable params: 15,892,549 (60.63 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### History Model VGG

# %%
history_model_VGG = model_VGG.fit(
    datagen.flow(train_X, train_Y, batch_size=64),
    epochs=30,
    validation_data=datagen.flow(val_X, val_Y)
)
# Out:
# Epoch 1/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 426s 9s/step - accuracy: 0.2903 - loss: 1.6466 - val_accuracy: 0.4226 - val_loss: 1.3204
# Epoch 2/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 325s 7s/step - accuracy: 0.4468 - loss: 1.2511 - val_accuracy: 0.4592 - val_loss: 1.2459
# Epoch 3/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 231s 5s/step - accuracy: 0.4951 - loss: 1.1855 - val_accuracy: 0.5149 - val_loss: 1.1466
# Epoch 4/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 316s 5s/step - accuracy: 0.5589 - loss: 1.0926 - val_accuracy: 0.5625 - val_loss: 1.0731
# Epoch 5/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 231s 5s/step - accuracy: 0.5502 - loss: 1.0673 - val_accuracy: 0.5666 - val_loss: 1.0686
# Epoch 6/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2493s 55s/step - accuracy: 0.5840 - loss: 1.0327 - val_accuracy: 0.6291 - val_loss: 0.9390
# Epoch 7/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3042s 66s/step - accuracy: 0.6461 - loss: 0.9414 - val_accuracy: 0.6617 - val_loss: 0.9217
# Epoch 8/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 276s 6s/step - accuracy: 0.6676 - loss: 0.8957 - val_accuracy: 0.6060 - val_loss: 0.9752
# Epoch 9/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 357s 7s/step - accuracy: 0.6728 - loss: 0.8714 - val_accuracy: 0.6359 - val_loss: 0.9262
# Epoch 10/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 389s 9s/step - accuracy: 0.6783 - loss: 0.8368 - val_accuracy: 0.6250 - val_loss: 0.9181
# Epoch 11/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 251s 5s/step - accuracy: 0.6919 - loss: 0.8256 - val_accuracy: 0.6440 - val_loss: 0.8939
# Epoch 12/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 750s 17s/step - accuracy: 0.6982 - loss: 0.7896 - val_accuracy: 0.6685 - val_loss: 0.8729
# Epoch 13/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 365s 8s/step - accuracy: 0.7193 - loss: 0.7498 - val_accuracy: 0.6617 - val_loss: 0.8714
# Epoch 14/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 601s 13s/step - accuracy: 0.7058 - loss: 0.7637 - val_accuracy: 0.6658 - val_loss: 0.8290
# Epoch 15/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 886s 20s/step - accuracy: 0.7339 - loss: 0.7177 - val_accuracy: 0.6861 - val_loss: 0.8321
# Epoch 16/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 228s 5s/step - accuracy: 0.7243 - loss: 0.7118 - val_accuracy: 0.6753 - val_loss: 0.8352
# Epoch 17/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 463s 10s/step - accuracy: 0.7243 - loss: 0.7391 - val_accuracy: 0.6508 - val_loss: 0.9132
# Epoch 18/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 235s 5s/step - accuracy: 0.7119 - loss: 0.7232 - val_accuracy: 0.6807 - val_loss: 0.8037
# Epoch 19/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2076s 46s/step - accuracy: 0.7408 - loss: 0.6714 - val_accuracy: 0.6970 - val_loss: 0.8110
# Epoch 20/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 266s 6s/step - accuracy: 0.7447 - loss: 0.6452 - val_accuracy: 0.7174 - val_loss: 0.7931
# Epoch 21/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 244s 5s/step - accuracy: 0.7678 - loss: 0.6278 - val_accuracy: 0.7215 - val_loss: 0.8369
# Epoch 22/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 332s 7s/step - accuracy: 0.7785 - loss: 0.5930 - val_accuracy: 0.6780 - val_loss: 0.8398
# Epoch 23/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 230s 5s/step - accuracy: 0.7897 - loss: 0.5786 - val_accuracy: 0.7215 - val_loss: 0.8012
# Epoch 24/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 226s 5s/step - accuracy: 0.7845 - loss: 0.5910 - val_accuracy: 0.6875 - val_loss: 0.8329
# Epoch 25/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 230s 5s/step - accuracy: 0.7695 - loss: 0.5924 - val_accuracy: 0.6848 - val_loss: 0.8045
# Epoch 26/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 225s 5s/step - accuracy: 0.7953 - loss: 0.5598 - val_accuracy: 0.7147 - val_loss: 0.7937
# Epoch 27/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 226s 5s/step - accuracy: 0.8112 - loss: 0.5212 - val_accuracy: 0.7174 - val_loss: 0.7833
# Epoch 28/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 225s 5s/step - accuracy: 0.8041 - loss: 0.5246 - val_accuracy: 0.7337 - val_loss: 0.7441
# Epoch 29/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 260s 6s/step - accuracy: 0.8194 - loss: 0.4959 - val_accuracy: 0.7038 - val_loss: 0.7975
# Epoch 30/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 226s 5s/step - accuracy: 0.8070 - loss: 0.5312 - val_accuracy: 0.7106 - val_loss: 0.7496

# %% [markdown]
# ### Plot Accuracy

# %%
plt.plot(history_model_VGG.history['accuracy'])
plt.plot(history_model_VGG.history['val_accuracy'])
plt.title('Training Accuracy vs Validation Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Plot Loss

# %%
plt.plot(history_model_VGG.history['loss'])
plt.plot(history_model_VGG.history['val_loss'])
plt.title('Training Loss vs Validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Accuracy and Loss

# %%
score = model_VGG.evaluate(test_X, test_Y, verbose=0)
print("Loss: " + str(score[0]))
print("Accuracy: " + str(score[1]*100) + "%")
# Out:
# Loss: 0.6055604815483093
# Accuracy: 77.21712589263916%
